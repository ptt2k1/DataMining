# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#!pip install unrar
# %cd /content/drive/MyDrive/myntradataset
# !unrar x /content/drive/MyDrive/myntradataset/images.rar

# %%
DATASET_PATH = "/content/drive/MyDrive/myntradataset/"
print(os.listdir(DATASET_PATH))
# Out:
# ['images.rar', 'styles.csv', 'visual_product_recommend.h5', 'model2.h5', 'alexnet.h5', 'images']

# %%
data_path = "/content/drive/MyDrive/myntradataset/images/"
print(len(os.listdir(data_path)))
# Out:
# 41906

# %%
# what is inside the main directory
list_directory = os.listdir(DATASET_PATH)
print(list_directory)

# each time directory files gets reordered. That's why needed to find where images folder is.
index=0
for i in range (len(list_directory)):
    if list_directory[i]=="images":
        index=i
        break

# what is in the image directory
imageIndex = os.listdir(DATASET_PATH+list_directory[index])
# print(type(imageIndex))
head = 10

# collecting some samples in list
sampleImages = []

# showing indices
for i in range (head):
    sampleImages.append(imageIndex[i])
    print(sampleImages[i])

# choosing some samples to observe
fig=plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)
axis=[]
row = len(sampleImages)/2
col = row+1

for i in range (len(sampleImages)):
    Image_path=DATASET_PATH+list_directory[index]+"/"+sampleImages[i]
    src = cv2.imread(Image_path)
    image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
    axis.append(fig.add_subplot(row, col, i+1))
    subplot_title=sampleImages[i]
    axis[-1].set_title(subplot_title)  
    plt.imshow(image)

fig.tight_layout()
plt.show()
# Out:
# ['images.rar', 'styles.csv', 'visual_product_recommend.h5', 'model2.h5', 'alexnet.h5', 'images']
# 10000.jpg
# 10001.jpg
# 10002.jpg
# 10003.jpg
# 10004.jpg
# 10005.jpg
# 10006.jpg
# 10007.jpg
# 10008.jpg
# 10009.jpg

# %%
df = pd.read_csv(DATASET_PATH + "styles.csv", nrows=50000, error_bad_lines=False)
df.drop(df.columns[0], axis=1, inplace=True)
df.head(10)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#      year   usage                             productDisplayName      image
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt  15970.jpg
# 1  2012.0  Casual             Peter England Men Party Blue Jeans  39386.jpg
# 2  2016.0  Casual                       Titan Women Silver Watch  59263.jpg
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants  21379.jpg
# 4  2012.0  Casual                          Puma Men Grey T-shirt  53759.jpg
# 5  2011.0  Casual           Inkfruit Mens Chain Reaction T-shirt   1855.jpg
# 6  2012.0  Ethnic               Fabindia Men Striped Green Shirt  30805.jpg
# 7  2012.0  Casual                  Jealous 21 Women Purple Shirt  26960.jpg
# 8  2012.0  Casual                       Puma Men Pack of 3 Socks  29114.jpg
# 9  2016.0  Casual                         Skagen Men Black Watch  30039.jpg

# %%
plt.figure(figsize=(8,6))
df['masterCategory'].value_counts().plot(kind='bar',x='type',y='filename')
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator

#image generator object from keras. reference : Keras Docs
image_generator = ImageDataGenerator(
    validation_split=0.2, rescale=1/255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True
)

#create a flow of images for training the model.
training_generator = image_generator.flow_from_dataframe(
    dataframe = df,
    directory= "/content/drive/MyDrive/myntradataset/images/",
    x_col="image",
    y_col="masterCategory",
    target_size=(227,227),
    batch_size=32,
    subset="training"

)

#create a flow of images for validating(testing) the trained model.
validation_generator = image_generator.flow_from_dataframe(
    dataframe = df,
    directory="/content/drive/MyDrive/myntradataset/images/",
    x_col="image",
    y_col="masterCategory",
    target_size=(227,227),
    batch_size=32,
    subset="validation"
)
# Out:
# Found 33525 validated image filenames belonging to 3 classes.
# Found 8381 validated image filenames belonging to 3 classes.

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Input,Dense,Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Model,Sequential

# %%
image_size=[227,227]
model=VGG16(input_shape=image_size+[3],include_top=False,weights="imagenet")
## We are going To use imagenet Weights
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step

# %%
for layers in model.layers:
  layers.trainable=False

# %%
final_model=Model(inputs=model.input,outputs=Dense(3,activation="softmax")(Flatten()(model.output)))
final_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 227, 227, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 227, 227, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 113, 113, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 113, 113, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 113, 113, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 3)                 75267
#
# =================================================================
# Total params: 14,789,955
# Trainable params: 75,267
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
final_model.compile(loss="binary_crossentropy",optimizer="adam",metrics=['accuracy'])

# %%
vgg16=final_model.fit(training_generator,epochs=50,steps_per_epoch=20,validation_data=validation_generator)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 138s 7s/step - loss: 0.3686 - accuracy: 0.7578 - val_loss: 0.1747 - val_accuracy: 0.9236
# Epoch 2/50
# 20/20 [==============================] - 124s 7s/step - loss: 0.1366 - accuracy: 0.9375 - val_loss: 0.1063 - val_accuracy: 0.9554
# Epoch 3/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0837 - accuracy: 0.9719 - val_loss: 0.1069 - val_accuracy: 0.9437
# Epoch 4/50
# 20/20 [==============================] - 124s 7s/step - loss: 0.0583 - accuracy: 0.9797 - val_loss: 0.0746 - val_accuracy: 0.9704
# Epoch 5/50
# 20/20 [==============================] - 127s 7s/step - loss: 0.0637 - accuracy: 0.9746 - val_loss: 0.0679 - val_accuracy: 0.9748
# Epoch 6/50
# 20/20 [==============================] - 126s 7s/step - loss: 0.0567 - accuracy: 0.9750 - val_loss: 0.0613 - val_accuracy: 0.9765
# Epoch 7/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0578 - accuracy: 0.9766 - val_loss: 0.0774 - val_accuracy: 0.9693
# Epoch 8/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0787 - accuracy: 0.9719 - val_loss: 0.0547 - val_accuracy: 0.9773
# Epoch 9/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0658 - accuracy: 0.9641 - val_loss: 0.0712 - val_accuracy: 0.9643
# Epoch 10/50
# 20/20 [==============================] - 150s 8s/step - loss: 0.0546 - accuracy: 0.9734 - val_loss: 0.0536 - val_accuracy: 0.9778
# Epoch 11/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0417 - accuracy: 0.9844 - val_loss: 0.0528 - val_accuracy: 0.9786
# Epoch 12/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0590 - accuracy: 0.9812 - val_loss: 0.0474 - val_accuracy: 0.9801
# Epoch 13/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0394 - accuracy: 0.9781 - val_loss: 0.0443 - val_accuracy: 0.9807
# Epoch 14/50
# 20/20 [==============================] - 126s 7s/step - loss: 0.0446 - accuracy: 0.9859 - val_loss: 0.0463 - val_accuracy: 0.9809
# Epoch 15/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0472 - accuracy: 0.9797 - val_loss: 0.0432 - val_accuracy: 0.9813
# Epoch 16/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0345 - accuracy: 0.9859 - val_loss: 0.0564 - val_accuracy: 0.9730
# Epoch 17/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0443 - accuracy: 0.9828 - val_loss: 0.0384 - val_accuracy: 0.9857
# Epoch 18/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0380 - accuracy: 0.9812 - val_loss: 0.0401 - val_accuracy: 0.9835
# Epoch 19/50
# 20/20 [==============================] - 122s 6s/step - loss: 0.0611 - accuracy: 0.9781 - val_loss: 0.0414 - val_accuracy: 0.9839
# Epoch 20/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0300 - accuracy: 0.9922 - val_loss: 0.0432 - val_accuracy: 0.9821
# Epoch 21/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0385 - accuracy: 0.9891 - val_loss: 0.0374 - val_accuracy: 0.9853
# Epoch 22/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0255 - accuracy: 0.9891 - val_loss: 0.0455 - val_accuracy: 0.9801
# Epoch 23/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0527 - accuracy: 0.9719 - val_loss: 0.0404 - val_accuracy: 0.9845
# Epoch 24/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0503 - accuracy: 0.9859 - val_loss: 0.0388 - val_accuracy: 0.9847
# Epoch 25/50
# 20/20 [==============================] - 124s 7s/step - loss: 0.0304 - accuracy: 0.9906 - val_loss: 0.0348 - val_accuracy: 0.9868
# Epoch 26/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0437 - accuracy: 0.9875 - val_loss: 0.0387 - val_accuracy: 0.9862
# Epoch 27/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0468 - accuracy: 0.9812 - val_loss: 0.0332 - val_accuracy: 0.9859
# Epoch 28/50
# 20/20 [==============================] - 124s 7s/step - loss: 0.0406 - accuracy: 0.9825 - val_loss: 0.0473 - val_accuracy: 0.9802
# Epoch 29/50
# 20/20 [==============================] - 126s 7s/step - loss: 0.0337 - accuracy: 0.9922 - val_loss: 0.0397 - val_accuracy: 0.9816
# Epoch 30/50
# 20/20 [==============================] - 124s 7s/step - loss: 0.0374 - accuracy: 0.9875 - val_loss: 0.0327 - val_accuracy: 0.9874
# Epoch 31/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0405 - accuracy: 0.9812 - val_loss: 0.0338 - val_accuracy: 0.9869
# Epoch 32/50
# 20/20 [==============================] - 126s 7s/step - loss: 0.0229 - accuracy: 0.9922 - val_loss: 0.0296 - val_accuracy: 0.9872
# Epoch 33/50
# 20/20 [==============================] - 127s 7s/step - loss: 0.0406 - accuracy: 0.9797 - val_loss: 0.0318 - val_accuracy: 0.9857
# Epoch 34/50
# 20/20 [==============================] - 150s 8s/step - loss: 0.0452 - accuracy: 0.9812 - val_loss: 0.0449 - val_accuracy: 0.9802
# Epoch 35/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0200 - accuracy: 0.9922 - val_loss: 0.0351 - val_accuracy: 0.9846
# Epoch 36/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0350 - accuracy: 0.9828 - val_loss: 0.0329 - val_accuracy: 0.9871
# Epoch 37/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0382 - accuracy: 0.9859 - val_loss: 0.0305 - val_accuracy: 0.9865
# Epoch 38/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0199 - accuracy: 0.9937 - val_loss: 0.0364 - val_accuracy: 0.9844
# Epoch 39/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0316 - accuracy: 0.9844 - val_loss: 0.0460 - val_accuracy: 0.9797
# Epoch 40/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0373 - accuracy: 0.9812 - val_loss: 0.0647 - val_accuracy: 0.9712
# Epoch 41/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0278 - accuracy: 0.9828 - val_loss: 0.0371 - val_accuracy: 0.9853
# Epoch 42/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0494 - accuracy: 0.9812 - val_loss: 0.0492 - val_accuracy: 0.9776
# Epoch 43/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0315 - accuracy: 0.9891 - val_loss: 0.0373 - val_accuracy: 0.9839
# Epoch 44/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0350 - accuracy: 0.9875 - val_loss: 0.0332 - val_accuracy: 0.9853
# Epoch 45/50
# 20/20 [==============================] - 121s 6s/step - loss: 0.0248 - accuracy: 0.9891 - val_loss: 0.0352 - val_accuracy: 0.9858
# Epoch 46/50
# 20/20 [==============================] - 150s 8s/step - loss: 0.0178 - accuracy: 0.9922 - val_loss: 0.0310 - val_accuracy: 0.9868
# Epoch 47/50
# 20/20 [==============================] - 122s 6s/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 0.0300 - val_accuracy: 0.9870
# Epoch 48/50
# 20/20 [==============================] - 122s 6s/step - loss: 0.0492 - accuracy: 0.9906 - val_loss: 0.0294 - val_accuracy: 0.9881
# Epoch 49/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0231 - accuracy: 0.9937 - val_loss: 0.0277 - val_accuracy: 0.9883
# Epoch 50/50
# 20/20 [==============================] - 150s 8s/step - loss: 0.0299 - accuracy: 0.9906 - val_loss: 0.0263 - val_accuracy: 0.9890

# %%
plt.figure(figsize=(20, 16))

plt.subplot(2, 2, 1)
plt.plot(vgg16.history['loss'], label='Loss')
plt.plot(vgg16.history['val_loss'], label='val_Loss')
plt.legend()
plt.grid()
plt.title('Loss evolution')

plt.subplot(2, 2, 2)
plt.plot(vgg16.history['accuracy'], label='accuracy')
plt.plot(vgg16.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.grid()
plt.title('Accuracy evolution')
# Out:
# Text(0.5, 1.0, 'Accuracy evolution')

# %%
final_model.save('VGG16tc.h5')

# %%
from keras import models
final_model = models.load_model('VGG16tc.h5')

# %%
#X_test, y_test = next(validation_generator)
#print(len(X_test))
batch_size = 32
#!pip install tqdm
import tqdm
validation_generator.reset()
X_test, y_test = next(validation_generator)
for i in tqdm.tqdm(range(int(validation_generator.n/batch_size)-200)): 
  img, label = next(validation_generator)
  X_test = np.append(X_test, img, axis=0 )
  y_test = np.append(y_test, label, axis=0)
#print(X_test.shape, y_test.shape)
# Out:
# 100%|██████████| 61/61 [00:52<00:00,  1.16it/s]

# %%
y_predict = final_model.predict(X_test)
predicted_classes = np.argmax(y_predict,axis=1)
# Out:
# 62/62 [==============================] - 8s 125ms/step

# %%
score = final_model.evaluate(X_test, y_test,verbose=0)
print(score)
# Out:
# [0.023411041125655174, 0.9879032373428345]

# %%
y_test = np.argmax(y_test, axis = 1)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predicted_classes)
plt.figure(figsize = (10,10))
sns.heatmap(cm, annot=True, cmap = 'Pastel1', fmt='g')

# %%
cm_df = pd.DataFrame(cm)
cm_df.columns = [ 'Predicted Accessories','Predicted Apparel', 'Predicted Footwear']
cm_final_df = cm_df.rename(index={0: 'Actually Accessories', 1: 'Actually Apparel', 2: 'Actually Footwear'})
cm_final_df
# Out:
#                       Predicted Accessories  Predicted Apparel  \
# Actually Accessories                    517                 10
# Actually Apparel                          9               1017
# Actually Footwear                         2                  0
#
#                       Predicted Footwear
# Actually Accessories                   3
# Actually Apparel                       0
# Actually Footwear                    426

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

Precision = precision_score(y_test, predicted_classes,average='macro')
Recall = recall_score(y_test, predicted_classes,average='macro')
F1_score = f1_score(y_test, predicted_classes, average='macro')

# %%
df_metrix = pd.DataFrame(data = [(Precision, Recall, F1_score)], columns = ['Precision', 'Recall', 'F1_score'])
df_metrix
# Out:
#    Precision    Recall  F1_score
# 0   0.987479  0.987342  0.987409

# %% [markdown]
# ## VGG19

# %%
image_size=[227,227]
model1=VGG19(input_shape=image_size+[3],include_top=False,weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 3s 0us/step

# %%
for layers in model1.layers:
  layers.trainable=False

final_model1=Model(inputs=model1.input,outputs=Dense(3,activation="softmax")(Flatten()(model1.output)))
final_model1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 227, 227, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 227, 227, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 113, 113, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 113, 113, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 113, 113, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 3)                 75267
#
# =================================================================
# Total params: 20,099,651
# Trainable params: 75,267
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
final_model1.compile(loss="binary_crossentropy",optimizer="adam",metrics=['accuracy'])
vgg19=final_model1.fit(training_generator,epochs=50,steps_per_epoch=20,validation_data=validation_generator)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 138s 7s/step - loss: 0.3008 - accuracy: 0.8203 - val_loss: 0.1443 - val_accuracy: 0.9251
# Epoch 2/50
# 20/20 [==============================] - 127s 7s/step - loss: 0.1090 - accuracy: 0.9484 - val_loss: 0.0957 - val_accuracy: 0.9570
# Epoch 3/50
# 20/20 [==============================] - 152s 8s/step - loss: 0.0841 - accuracy: 0.9656 - val_loss: 0.0806 - val_accuracy: 0.9668
# Epoch 4/50
# 20/20 [==============================] - 125s 7s/step - loss: 0.0823 - accuracy: 0.9672 - val_loss: 0.0807 - val_accuracy: 0.9630
# Epoch 5/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0576 - accuracy: 0.9781 - val_loss: 0.0817 - val_accuracy: 0.9642
# Epoch 6/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0719 - accuracy: 0.9719 - val_loss: 0.0915 - val_accuracy: 0.9535
# Epoch 7/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0654 - accuracy: 0.9688 - val_loss: 0.0663 - val_accuracy: 0.9720
# Epoch 8/50
# 20/20 [==============================] - 124s 6s/step - loss: 0.0548 - accuracy: 0.9797 - val_loss: 0.0576 - val_accuracy: 0.9759
# Epoch 9/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0476 - accuracy: 0.9781 - val_loss: 0.0551 - val_accuracy: 0.9774
# Epoch 10/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0574 - accuracy: 0.9781 - val_loss: 0.0556 - val_accuracy: 0.9785
# Epoch 11/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0417 - accuracy: 0.9812 - val_loss: 0.0502 - val_accuracy: 0.9798
# Epoch 12/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0563 - accuracy: 0.9656 - val_loss: 0.0490 - val_accuracy: 0.9798
# Epoch 13/50
# 20/20 [==============================] - 124s 7s/step - loss: 0.0508 - accuracy: 0.9781 - val_loss: 0.0486 - val_accuracy: 0.9804
# Epoch 14/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0847 - accuracy: 0.9656 - val_loss: 0.0523 - val_accuracy: 0.9802
# Epoch 15/50
# 20/20 [==============================] - 126s 7s/step - loss: 0.0495 - accuracy: 0.9828 - val_loss: 0.0479 - val_accuracy: 0.9817
# Epoch 16/50
# 20/20 [==============================] - 152s 8s/step - loss: 0.0583 - accuracy: 0.9766 - val_loss: 0.0454 - val_accuracy: 0.9816
# Epoch 17/50
# 20/20 [==============================] - 121s 6s/step - loss: 0.0565 - accuracy: 0.9750 - val_loss: 0.0566 - val_accuracy: 0.9748
# Epoch 18/50
# 20/20 [==============================] - 120s 6s/step - loss: 0.0361 - accuracy: 0.9828 - val_loss: 0.0482 - val_accuracy: 0.9800
# Epoch 19/50
# 20/20 [==============================] - 120s 6s/step - loss: 0.0463 - accuracy: 0.9812 - val_loss: 0.0435 - val_accuracy: 0.9837
# Epoch 20/50
# 20/20 [==============================] - 120s 6s/step - loss: 0.0435 - accuracy: 0.9812 - val_loss: 0.0401 - val_accuracy: 0.9835
# Epoch 21/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0493 - accuracy: 0.9828 - val_loss: 0.0416 - val_accuracy: 0.9829
# Epoch 22/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0467 - accuracy: 0.9750 - val_loss: 0.0427 - val_accuracy: 0.9837
# Epoch 23/50
# 20/20 [==============================] - 121s 6s/step - loss: 0.0317 - accuracy: 0.9891 - val_loss: 0.0558 - val_accuracy: 0.9755
# Epoch 24/50
# 20/20 [==============================] - 122s 6s/step - loss: 0.0600 - accuracy: 0.9734 - val_loss: 0.0443 - val_accuracy: 0.9823
# Epoch 25/50
# 20/20 [==============================] - 122s 6s/step - loss: 0.0319 - accuracy: 0.9859 - val_loss: 0.0413 - val_accuracy: 0.9806
# Epoch 26/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0329 - accuracy: 0.9906 - val_loss: 0.0444 - val_accuracy: 0.9843
# Epoch 27/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0340 - accuracy: 0.9844 - val_loss: 0.0425 - val_accuracy: 0.9829
# Epoch 28/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0431 - accuracy: 0.9812 - val_loss: 0.0573 - val_accuracy: 0.9702
# Epoch 29/50
# 20/20 [==============================] - 122s 6s/step - loss: 0.0394 - accuracy: 0.9844 - val_loss: 0.0549 - val_accuracy: 0.9751
# Epoch 30/50
# 20/20 [==============================] - 123s 6s/step - loss: 0.0566 - accuracy: 0.9746 - val_loss: 0.0408 - val_accuracy: 0.9823
# Epoch 31/50
# 20/20 [==============================] - 121s 6s/step - loss: 0.0425 - accuracy: 0.9875 - val_loss: 0.0443 - val_accuracy: 0.9845
# Epoch 32/50
# 20/20 [==============================] - 121s 6s/step - loss: 0.0242 - accuracy: 0.9922 - val_loss: 0.0579 - val_accuracy: 0.9724
# Epoch 33/50
# 20/20 [==============================] - 120s 6s/step - loss: 0.0566 - accuracy: 0.9750 - val_loss: 0.0369 - val_accuracy: 0.9828
# Epoch 34/50
# 20/20 [==============================] - 121s 6s/step - loss: 0.0392 - accuracy: 0.9812 - val_loss: 0.0400 - val_accuracy: 0.9828
# Epoch 35/50
# 20/20 [==============================] - 120s 6s/step - loss: 0.0256 - accuracy: 0.9875 - val_loss: 0.0370 - val_accuracy: 0.9852
# Epoch 36/50
# 20/20 [==============================] - 122s 6s/step - loss: 0.0467 - accuracy: 0.9812 - val_loss: 0.0449 - val_accuracy: 0.9800
# Epoch 37/50
# 20/20 [==============================] - 121s 6s/step - loss: 0.0507 - accuracy: 0.9797 - val_loss: 0.0420 - val_accuracy: 0.9829
# Epoch 38/50
# 20/20 [==============================] - 122s 6s/step - loss: 0.0393 - accuracy: 0.9797 - val_loss: 0.0389 - val_accuracy: 0.9813
# Epoch 39/50
# 20/20 [==============================] - 121s 6s/step - loss: 0.0336 - accuracy: 0.9844 - val_loss: 0.0336 - val_accuracy: 0.9851
# Epoch 40/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0290 - accuracy: 0.9906 - val_loss: 0.0344 - val_accuracy: 0.9868
# Epoch 41/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0366 - accuracy: 0.9828 - val_loss: 0.0484 - val_accuracy: 0.9782
# Epoch 42/50
# 20/20 [==============================] - 122s 6s/step - loss: 0.0364 - accuracy: 0.9812 - val_loss: 0.0353 - val_accuracy: 0.9846
# Epoch 43/50
# 20/20 [==============================] - 120s 6s/step - loss: 0.0431 - accuracy: 0.9844 - val_loss: 0.0331 - val_accuracy: 0.9862
# Epoch 44/50
# 20/20 [==============================] - 120s 6s/step - loss: 0.0496 - accuracy: 0.9703 - val_loss: 0.0439 - val_accuracy: 0.9803
# Epoch 45/50
# 20/20 [==============================] - 120s 6s/step - loss: 0.0387 - accuracy: 0.9781 - val_loss: 0.0379 - val_accuracy: 0.9869
# Epoch 46/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0405 - accuracy: 0.9906 - val_loss: 0.0426 - val_accuracy: 0.9839
# Epoch 47/50
# 20/20 [==============================] - 119s 6s/step - loss: 0.0314 - accuracy: 0.9875 - val_loss: 0.0400 - val_accuracy: 0.9814
# Epoch 48/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0424 - accuracy: 0.9891 - val_loss: 0.0348 - val_accuracy: 0.9833
# Epoch 49/50
# 20/20 [==============================] - 119s 6s/step - loss: 0.0453 - accuracy: 0.9781 - val_loss: 0.0359 - val_accuracy: 0.9823
# Epoch 50/50
# 20/20 [==============================] - 151s 8s/step - loss: 0.0402 - accuracy: 0.9859 - val_loss: 0.0368 - val_accuracy: 0.9811

# %%
plt.figure(figsize=(20, 16))

plt.subplot(2, 2, 1)
plt.plot(vgg19.history['loss'], label='Loss')
plt.plot(vgg19.history['val_loss'], label='val_Loss')
plt.legend()
plt.grid()
plt.title('Loss evolution')

plt.subplot(2, 2, 2)
plt.plot(vgg19.history['accuracy'], label='accuracy')
plt.plot(vgg19.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.grid()
plt.title('Accuracy evolution')
# Out:
# Text(0.5, 1.0, 'Accuracy evolution')

# %%
final_model1.save('VGG19tc.h5')

# %%
from keras import models
final_model1 = models.load_model('VGG19tc.h5')

# %%
y_predict1 = final_model1.predict(X_test)
predicted_classes1 = np.argmax(y_predict1,axis=1)
#y_test = np.argmax(y_test, axis = 1)
# Out:
# 62/62 [==============================] - 9s 150ms/step

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(y_test, predicted_classes1)
plt.figure(figsize = (10,10))
sns.heatmap(cm1, annot=True, cmap = 'Pastel1', fmt = 'g')

# %%
cm_df1 = pd.DataFrame(cm1)
cm_df1.columns = [ 'Predicted Accessories','Predicted Apparel', 'Predicted Footwear']
cm_final_df1 = cm_df1.rename(index={0: 'Actually Accessories', 1: 'Actually Apparel', 2: 'Actually Footwear'})
cm_final_df1
# Out:
#                       Predicted Accessories  Predicted Apparel  \
# Actually Accessories                    523                  4
# Actually Apparel                         13               1004
# Actually Footwear                         2                  0
#
#                       Predicted Footwear
# Actually Accessories                   0
# Actually Apparel                       1
# Actually Footwear                    437

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

Precision1 = precision_score(y_test, predicted_classes1,average= 'macro')
Recall1 = recall_score(y_test, predicted_classes1,average='macro')
F1_score1 = f1_score(y_test, predicted_classes1, average='macro')

df_metrix1 = pd.DataFrame(data = [(Precision1, Recall1, F1_score1)], columns = ['Precision', 'Recall', 'F1_score'])
df_metrix1
# Out:
#    Precision    Recall  F1_score
# 0   0.988623  0.991367  0.989951
