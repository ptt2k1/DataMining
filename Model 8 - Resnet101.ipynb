# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !pip install unrar
# %cd /content/drive/MyDrive/myntradataset
# !unrar x /content/drive/MyDrive/myntradataset/images.rar

# %%
DATASET_PATH = "/content/drive/MyDrive/myntradataset/"
print(os.listdir(DATASET_PATH))
# Out:
# ['images.rar', 'styles.csv', 'VGG16.h5', 'VGG19.h5', 'resnet101.h5', 'images']

# %%
data_path = "/content/drive/MyDrive/myntradataset/images/"
print(len(os.listdir(data_path)))
# Out:
# 41906

# %%
# what is inside the main directory
list_directory = os.listdir(DATASET_PATH)
print(list_directory)

# each time directory files gets reordered. That's why needed to find where images folder is.
index=0
for i in range (len(list_directory)):
    if list_directory[i]=="images":
        index=i
        break

# what is in the image directory
imageIndex = os.listdir(DATASET_PATH+list_directory[index])
# print(type(imageIndex))
head = 10

# collecting some samples in list
sampleImages = []

# showing indices
for i in range (head):
    sampleImages.append(imageIndex[i])
    print(sampleImages[i])

# choosing some samples to observe
fig=plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)
axis=[]
row = len(sampleImages)/2
col = row+1

for i in range (len(sampleImages)):
    Image_path=DATASET_PATH+list_directory[index]+"/"+sampleImages[i]
    src = cv2.imread(Image_path)
    image = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) 
    axis.append(fig.add_subplot(row, col, i+1))
    subplot_title=sampleImages[i]
    axis[-1].set_title(subplot_title)  
    plt.imshow(image)

fig.tight_layout()
plt.show()
# Out:
# ['images.rar', 'styles.csv', 'VGG16.h5', 'VGG19.h5', 'resnet101.h5', 'images']
# 10000.jpg
# 10001.jpg
# 10002.jpg
# 10003.jpg
# 10004.jpg
# 10005.jpg
# 10006.jpg
# 10007.jpg
# 10008.jpg
# 10009.jpg

# %%
df = pd.read_csv(DATASET_PATH + "styles.csv", nrows=50000, error_bad_lines=False)
df.drop(df.columns[0], axis=1, inplace=True)
df.head(10)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#      year   usage                             productDisplayName      image
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt  15970.jpg
# 1  2012.0  Casual             Peter England Men Party Blue Jeans  39386.jpg
# 2  2016.0  Casual                       Titan Women Silver Watch  59263.jpg
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants  21379.jpg
# 4  2012.0  Casual                          Puma Men Grey T-shirt  53759.jpg
# 5  2011.0  Casual           Inkfruit Mens Chain Reaction T-shirt   1855.jpg
# 6  2012.0  Ethnic               Fabindia Men Striped Green Shirt  30805.jpg
# 7  2012.0  Casual                  Jealous 21 Women Purple Shirt  26960.jpg
# 8  2012.0  Casual                       Puma Men Pack of 3 Socks  29114.jpg
# 9  2016.0  Casual                         Skagen Men Black Watch  30039.jpg

# %%
from keras.preprocessing.image import ImageDataGenerator

#image generator object from keras. reference : Keras Docs
image_generator = ImageDataGenerator(
    validation_split=0.2, rescale=1/255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True
)

#create a flow of images for training the model.
training_generator = image_generator.flow_from_dataframe(
    dataframe = df,
    directory= "/content/drive/MyDrive/myntradataset/images/",
    x_col="image",
    y_col="masterCategory",
    target_size=(227,227),
    batch_size=32,
    subset="training"

)

#create a flow of images for validating(testing) the trained model.
validation_generator = image_generator.flow_from_dataframe(
    dataframe = df,
    directory="/content/drive/MyDrive/myntradataset/images/",
    x_col="image",
    y_col="masterCategory",
    target_size=(227,227),
    batch_size=32,
    subset="validation"
)
# Out:
# Found 33525 validated image filenames belonging to 3 classes.
# Found 8381 validated image filenames belonging to 3 classes.

# %%
from tensorflow.keras.applications import ResNet101
from tensorflow.keras.layers import Input,Dense,Flatten,Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Model

# %%
image_size=[227,227]
model=ResNet101(input_shape=image_size+[3],include_top=False,weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 8s 0us/step

# %%
for layers in model.layers:
  layers.trainable=False

# %%
final_model=Model(inputs=model.input,outputs=Dense(3,activation="softmax")(Flatten()(model.output)))

# %%
final_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 233, 233, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 114, 114, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 114, 114, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 114, 114, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 116, 116, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 57, 57, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 57, 57, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 57, 57, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 57, 57, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 57, 57, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 57, 57, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 57, 57, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 57, 57, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 57, 57, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 57, 57, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 57, 57, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 57, 57, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 57, 57, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 57, 57, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 57, 57, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 57, 57, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 57, 57, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 57, 57, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 57, 57, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 57, 57, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 57, 57, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 57, 57, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 57, 57, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 57, 57, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 57, 57, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 57, 57, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 57, 57, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 57, 57, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 57, 57, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 57, 57, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 57, 57, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 57, 57, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 57, 57, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 29, 29, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 29, 29, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 29, 29, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 29, 29, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 29, 29, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 29, 29, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 29, 29, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 29, 29, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 29, 29, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 29, 29, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 29, 29, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 29, 29, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 29, 29, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 29, 29, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 29, 29, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 29, 29, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 29, 29, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 29, 29, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 29, 29, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 29, 29, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 29, 29, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 29, 29, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 29, 29, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 29, 29, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 29, 29, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 29, 29, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 29, 29, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 29, 29, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 29, 29, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 29, 29, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 29, 29, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 29, 29, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 29, 29, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 29, 29, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 29, 29, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 29, 29, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 29, 29, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 29, 29, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 29, 29, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 29, 29, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 29, 29, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 29, 29, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 15, 15, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 15, 15, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 15, 15, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 15, 15, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 15, 15, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 15, 15, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 15, 15, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 15, 15, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 15, 15, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 15, 15, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 15, 15, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 15, 15, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 15, 15, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 15, 15, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 15, 15, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 15, 15, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 15, 15, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 15, 15, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 15, 15, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 15, 15, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 15, 15, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 15, 15, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 15, 15, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 15, 15, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 15, 15, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 15, 15, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 15, 15, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 15, 15, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 15, 15, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 15, 15, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 15, 15, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv4_block7_1_conv (Conv2D)   (None, 15, 15, 256)  262400      ['conv4_block6_out[0][0]']
#
#  conv4_block7_1_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block7_1_conv[0][0]']
#  ization)
#
#  conv4_block7_1_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block7_1_bn[0][0]']
#  n)
#
#  conv4_block7_2_conv (Conv2D)   (None, 15, 15, 256)  590080      ['conv4_block7_1_relu[0][0]']
#
#  conv4_block7_2_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block7_2_conv[0][0]']
#  ization)
#
#  conv4_block7_2_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block7_2_bn[0][0]']
#  n)
#
#  conv4_block7_3_conv (Conv2D)   (None, 15, 15, 1024  263168      ['conv4_block7_2_relu[0][0]']
#                                 )
#
#  conv4_block7_3_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block7_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block7_add (Add)         (None, 15, 15, 1024  0           ['conv4_block6_out[0][0]',
#                                 )                                 'conv4_block7_3_bn[0][0]']
#
#  conv4_block7_out (Activation)  (None, 15, 15, 1024  0           ['conv4_block7_add[0][0]']
#                                 )
#
#  conv4_block8_1_conv (Conv2D)   (None, 15, 15, 256)  262400      ['conv4_block7_out[0][0]']
#
#  conv4_block8_1_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block8_1_conv[0][0]']
#  ization)
#
#  conv4_block8_1_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block8_1_bn[0][0]']
#  n)
#
#  conv4_block8_2_conv (Conv2D)   (None, 15, 15, 256)  590080      ['conv4_block8_1_relu[0][0]']
#
#  conv4_block8_2_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block8_2_conv[0][0]']
#  ization)
#
#  conv4_block8_2_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block8_2_bn[0][0]']
#  n)
#
#  conv4_block8_3_conv (Conv2D)   (None, 15, 15, 1024  263168      ['conv4_block8_2_relu[0][0]']
#                                 )
#
#  conv4_block8_3_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block8_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block8_add (Add)         (None, 15, 15, 1024  0           ['conv4_block7_out[0][0]',
#                                 )                                 'conv4_block8_3_bn[0][0]']
#
#  conv4_block8_out (Activation)  (None, 15, 15, 1024  0           ['conv4_block8_add[0][0]']
#                                 )
#
#  conv4_block9_1_conv (Conv2D)   (None, 15, 15, 256)  262400      ['conv4_block8_out[0][0]']
#
#  conv4_block9_1_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block9_1_conv[0][0]']
#  ization)
#
#  conv4_block9_1_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block9_1_bn[0][0]']
#  n)
#
#  conv4_block9_2_conv (Conv2D)   (None, 15, 15, 256)  590080      ['conv4_block9_1_relu[0][0]']
#
#  conv4_block9_2_bn (BatchNormal  (None, 15, 15, 256)  1024       ['conv4_block9_2_conv[0][0]']
#  ization)
#
#  conv4_block9_2_relu (Activatio  (None, 15, 15, 256)  0          ['conv4_block9_2_bn[0][0]']
#  n)
#
#  conv4_block9_3_conv (Conv2D)   (None, 15, 15, 1024  263168      ['conv4_block9_2_relu[0][0]']
#                                 )
#
#  conv4_block9_3_bn (BatchNormal  (None, 15, 15, 1024  4096       ['conv4_block9_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block9_add (Add)         (None, 15, 15, 1024  0           ['conv4_block8_out[0][0]',
#                                 )                                 'conv4_block9_3_bn[0][0]']
#
#  conv4_block9_out (Activation)  (None, 15, 15, 1024  0           ['conv4_block9_add[0][0]']
#                                 )
#
#  conv4_block10_1_conv (Conv2D)  (None, 15, 15, 256)  262400      ['conv4_block9_out[0][0]']
#
#  conv4_block10_1_bn (BatchNorma  (None, 15, 15, 256)  1024       ['conv4_block10_1_conv[0][0]']
#  lization)
#
#  conv4_block10_1_relu (Activati  (None, 15, 15, 256)  0          ['conv4_block10_1_bn[0][0]']
#  on)
#
#  conv4_block10_2_conv (Conv2D)  (None, 15, 15, 256)  590080      ['conv4_block10_1_relu[0][0]']
#
#  conv4_block10_2_bn (BatchNorma  (None, 15, 15, 256)  1024       ['conv4_block10_2_conv[0][0]']
#  lization)
# ...
#  conv4_block21_2_relu (Activati  (None, 15, 15, 256)  0          ['conv4_block21_2_bn[0][0]']
#  on)
#
#  conv4_block21_3_conv (Conv2D)  (None, 15, 15, 1024  263168      ['conv4_block21_2_relu[0][0]']
#                                 )
#
#  conv4_block21_3_bn (BatchNorma  (None, 15, 15, 1024  4096       ['conv4_block21_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block21_add (Add)        (None, 15, 15, 1024  0           ['conv4_block20_out[0][0]',
#                                 )                                 'conv4_block21_3_bn[0][0]']
#
#  conv4_block21_out (Activation)  (None, 15, 15, 1024  0          ['conv4_block21_add[0][0]']
#                                 )
#
#  conv4_block22_1_conv (Conv2D)  (None, 15, 15, 256)  262400      ['conv4_block21_out[0][0]']
#
#  conv4_block22_1_bn (BatchNorma  (None, 15, 15, 256)  1024       ['conv4_block22_1_conv[0][0]']
#  lization)
#
#  conv4_block22_1_relu (Activati  (None, 15, 15, 256)  0          ['conv4_block22_1_bn[0][0]']
#  on)
#
#  conv4_block22_2_conv (Conv2D)  (None, 15, 15, 256)  590080      ['conv4_block22_1_relu[0][0]']
#
#  conv4_block22_2_bn (BatchNorma  (None, 15, 15, 256)  1024       ['conv4_block22_2_conv[0][0]']
#  lization)
#
#  conv4_block22_2_relu (Activati  (None, 15, 15, 256)  0          ['conv4_block22_2_bn[0][0]']
#  on)
#
#  conv4_block22_3_conv (Conv2D)  (None, 15, 15, 1024  263168      ['conv4_block22_2_relu[0][0]']
#                                 )
#
#  conv4_block22_3_bn (BatchNorma  (None, 15, 15, 1024  4096       ['conv4_block22_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block22_add (Add)        (None, 15, 15, 1024  0           ['conv4_block21_out[0][0]',
#                                 )                                 'conv4_block22_3_bn[0][0]']
#
#  conv4_block22_out (Activation)  (None, 15, 15, 1024  0          ['conv4_block22_add[0][0]']
#                                 )
#
#  conv4_block23_1_conv (Conv2D)  (None, 15, 15, 256)  262400      ['conv4_block22_out[0][0]']
#
#  conv4_block23_1_bn (BatchNorma  (None, 15, 15, 256)  1024       ['conv4_block23_1_conv[0][0]']
#  lization)
#
#  conv4_block23_1_relu (Activati  (None, 15, 15, 256)  0          ['conv4_block23_1_bn[0][0]']
#  on)
#
#  conv4_block23_2_conv (Conv2D)  (None, 15, 15, 256)  590080      ['conv4_block23_1_relu[0][0]']
#
#  conv4_block23_2_bn (BatchNorma  (None, 15, 15, 256)  1024       ['conv4_block23_2_conv[0][0]']
#  lization)
#
#  conv4_block23_2_relu (Activati  (None, 15, 15, 256)  0          ['conv4_block23_2_bn[0][0]']
#  on)
#
#  conv4_block23_3_conv (Conv2D)  (None, 15, 15, 1024  263168      ['conv4_block23_2_relu[0][0]']
#                                 )
#
#  conv4_block23_3_bn (BatchNorma  (None, 15, 15, 1024  4096       ['conv4_block23_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block23_add (Add)        (None, 15, 15, 1024  0           ['conv4_block22_out[0][0]',
#                                 )                                 'conv4_block23_3_bn[0][0]']
#
#  conv4_block23_out (Activation)  (None, 15, 15, 1024  0          ['conv4_block23_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 8, 8, 512)    524800      ['conv4_block23_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 8, 8, 2048)   2099200     ['conv4_block23_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 8, 8, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 8, 8, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten (Flatten)              (None, 131072)       0           ['conv5_block3_out[0][0]']
#
#  dense (Dense)                  (None, 3)            393219      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 43,051,395
# Trainable params: 393,219
# Non-trainable params: 42,658,176
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
final_model.compile(loss="categorical_crossentropy",optimizer=RMSprop(lr=0.001),metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.

# %%
resnet = final_model.fit(training_generator,epochs=50,steps_per_epoch=20,validation_data=validation_generator)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 167s 8s/step - loss: 21.4317 - accuracy: 0.4594 - val_loss: 17.2074 - val_accuracy: 0.3064
# Epoch 2/50
# 20/20 [==============================] - 135s 7s/step - loss: 10.9801 - accuracy: 0.5156 - val_loss: 9.9939 - val_accuracy: 0.3416
# Epoch 3/50
# 20/20 [==============================] - 131s 7s/step - loss: 9.1420 - accuracy: 0.5344 - val_loss: 2.8896 - val_accuracy: 0.7173
# Epoch 4/50
# 20/20 [==============================] - 133s 7s/step - loss: 7.7998 - accuracy: 0.6187 - val_loss: 11.1940 - val_accuracy: 0.4616
# Epoch 5/50
# 20/20 [==============================] - 131s 7s/step - loss: 7.2620 - accuracy: 0.6344 - val_loss: 1.7634 - val_accuracy: 0.7735
# Epoch 6/50
# 20/20 [==============================] - 152s 8s/step - loss: 8.9163 - accuracy: 0.6219 - val_loss: 9.1546 - val_accuracy: 0.5289
# Epoch 7/50
# 20/20 [==============================] - 132s 7s/step - loss: 8.0922 - accuracy: 0.6156 - val_loss: 2.2230 - val_accuracy: 0.7295
# Epoch 8/50
# 20/20 [==============================] - 135s 7s/step - loss: 6.3058 - accuracy: 0.6828 - val_loss: 7.9861 - val_accuracy: 0.6704
# Epoch 9/50
# 20/20 [==============================] - 152s 8s/step - loss: 8.0988 - accuracy: 0.6656 - val_loss: 1.2923 - val_accuracy: 0.8290
# Epoch 10/50
# 20/20 [==============================] - 133s 7s/step - loss: 6.7987 - accuracy: 0.6672 - val_loss: 1.4492 - val_accuracy: 0.8350
# Epoch 11/50
# 20/20 [==============================] - 133s 7s/step - loss: 6.6621 - accuracy: 0.6609 - val_loss: 7.6711 - val_accuracy: 0.6344
# Epoch 12/50
# 20/20 [==============================] - 131s 7s/step - loss: 5.2614 - accuracy: 0.7266 - val_loss: 1.6616 - val_accuracy: 0.8145
# Epoch 13/50
# 20/20 [==============================] - 132s 7s/step - loss: 5.6493 - accuracy: 0.7250 - val_loss: 2.5736 - val_accuracy: 0.7843
# Epoch 14/50
# 20/20 [==============================] - 130s 7s/step - loss: 5.9129 - accuracy: 0.7203 - val_loss: 2.9311 - val_accuracy: 0.7660
# Epoch 15/50
# 20/20 [==============================] - 130s 7s/step - loss: 5.6814 - accuracy: 0.7266 - val_loss: 3.0327 - val_accuracy: 0.7926
# Epoch 16/50
# 20/20 [==============================] - 131s 7s/step - loss: 5.6356 - accuracy: 0.7266 - val_loss: 7.0415 - val_accuracy: 0.6979
# Epoch 17/50
# 20/20 [==============================] - 132s 7s/step - loss: 6.3040 - accuracy: 0.7000 - val_loss: 3.4532 - val_accuracy: 0.7222
# Epoch 18/50
# 20/20 [==============================] - 132s 7s/step - loss: 4.5238 - accuracy: 0.7437 - val_loss: 2.1799 - val_accuracy: 0.8155
# Epoch 19/50
# 20/20 [==============================] - 131s 7s/step - loss: 4.2129 - accuracy: 0.7758 - val_loss: 8.4079 - val_accuracy: 0.6599
# Epoch 20/50
# 20/20 [==============================] - 132s 7s/step - loss: 5.0281 - accuracy: 0.7656 - val_loss: 1.6728 - val_accuracy: 0.8191
# Epoch 21/50
# 20/20 [==============================] - 133s 7s/step - loss: 5.7765 - accuracy: 0.7188 - val_loss: 2.6588 - val_accuracy: 0.7733
# Epoch 22/50
# 20/20 [==============================] - 131s 7s/step - loss: 6.1212 - accuracy: 0.7172 - val_loss: 1.8756 - val_accuracy: 0.8390
# Epoch 23/50
# 20/20 [==============================] - 152s 8s/step - loss: 5.1234 - accuracy: 0.7578 - val_loss: 1.3522 - val_accuracy: 0.8561
# Epoch 24/50
# 20/20 [==============================] - 132s 7s/step - loss: 5.4650 - accuracy: 0.7406 - val_loss: 1.8749 - val_accuracy: 0.8394
# Epoch 25/50
# 20/20 [==============================] - 131s 7s/step - loss: 4.8467 - accuracy: 0.7437 - val_loss: 2.5458 - val_accuracy: 0.7972
# Epoch 26/50
# 20/20 [==============================] - 134s 7s/step - loss: 4.9977 - accuracy: 0.7547 - val_loss: 1.6991 - val_accuracy: 0.8541
# Epoch 27/50
# 20/20 [==============================] - 132s 7s/step - loss: 4.3313 - accuracy: 0.7859 - val_loss: 8.4333 - val_accuracy: 0.5489
# Epoch 28/50
# 20/20 [==============================] - 132s 7s/step - loss: 4.6142 - accuracy: 0.7719 - val_loss: 1.0927 - val_accuracy: 0.8782
# Epoch 29/50
# 20/20 [==============================] - 132s 7s/step - loss: 5.3692 - accuracy: 0.7578 - val_loss: 3.0620 - val_accuracy: 0.7492
# Epoch 30/50
# 20/20 [==============================] - 152s 8s/step - loss: 4.4785 - accuracy: 0.7563 - val_loss: 3.1249 - val_accuracy: 0.7633
# Epoch 31/50
# 20/20 [==============================] - 131s 7s/step - loss: 4.6085 - accuracy: 0.7891 - val_loss: 3.3903 - val_accuracy: 0.8009
# Epoch 32/50
# 20/20 [==============================] - 131s 7s/step - loss: 5.1010 - accuracy: 0.7547 - val_loss: 2.3883 - val_accuracy: 0.7962
# Epoch 33/50
# 20/20 [==============================] - 130s 7s/step - loss: 5.0462 - accuracy: 0.7719 - val_loss: 1.4986 - val_accuracy: 0.8562
# Epoch 34/50
# 20/20 [==============================] - 130s 7s/step - loss: 4.3274 - accuracy: 0.7906 - val_loss: 1.4966 - val_accuracy: 0.8535
# Epoch 35/50
# 20/20 [==============================] - 128s 7s/step - loss: 5.1050 - accuracy: 0.7656 - val_loss: 1.4541 - val_accuracy: 0.8642
# Epoch 36/50
# 20/20 [==============================] - 129s 7s/step - loss: 5.4121 - accuracy: 0.7437 - val_loss: 3.0146 - val_accuracy: 0.8007
# Epoch 37/50
# 20/20 [==============================] - 129s 7s/step - loss: 2.8623 - accuracy: 0.8344 - val_loss: 3.7097 - val_accuracy: 0.7275
# Epoch 38/50
# 20/20 [==============================] - 130s 7s/step - loss: 5.1113 - accuracy: 0.7656 - val_loss: 1.0392 - val_accuracy: 0.8926
# Epoch 39/50
# 20/20 [==============================] - 151s 8s/step - loss: 4.7579 - accuracy: 0.7484 - val_loss: 3.5867 - val_accuracy: 0.7443
# Epoch 40/50
# 20/20 [==============================] - 129s 7s/step - loss: 3.0759 - accuracy: 0.8078 - val_loss: 1.3440 - val_accuracy: 0.8771
# Epoch 41/50
# 20/20 [==============================] - 132s 7s/step - loss: 4.9387 - accuracy: 0.7578 - val_loss: 2.1497 - val_accuracy: 0.8210
# Epoch 42/50
# 20/20 [==============================] - 131s 7s/step - loss: 4.3239 - accuracy: 0.7891 - val_loss: 1.9366 - val_accuracy: 0.8550
# Epoch 43/50
# 20/20 [==============================] - 127s 7s/step - loss: 4.5755 - accuracy: 0.7703 - val_loss: 7.5160 - val_accuracy: 0.7364
# Epoch 44/50
# 20/20 [==============================] - 132s 7s/step - loss: 4.0252 - accuracy: 0.8109 - val_loss: 3.2033 - val_accuracy: 0.8240
# Epoch 45/50
# 20/20 [==============================] - 132s 7s/step - loss: 5.3581 - accuracy: 0.7641 - val_loss: 10.9080 - val_accuracy: 0.7116
# Epoch 46/50
# 20/20 [==============================] - 130s 7s/step - loss: 4.5887 - accuracy: 0.7859 - val_loss: 1.7169 - val_accuracy: 0.8619
# Epoch 47/50
# 20/20 [==============================] - 131s 7s/step - loss: 4.6076 - accuracy: 0.7734 - val_loss: 4.2487 - val_accuracy: 0.8122
# Epoch 48/50
# 20/20 [==============================] - 128s 7s/step - loss: 4.1910 - accuracy: 0.8047 - val_loss: 2.2801 - val_accuracy: 0.8353
# Epoch 49/50
# 20/20 [==============================] - 127s 7s/step - loss: 4.0027 - accuracy: 0.7969 - val_loss: 2.0637 - val_accuracy: 0.8337
# Epoch 50/50
# 20/20 [==============================] - 128s 7s/step - loss: 3.3129 - accuracy: 0.8219 - val_loss: 12.6244 - val_accuracy: 0.7182

# %%
plt.figure(figsize=(20, 16))

plt.subplot(2, 2, 1)
plt.plot(final_model.history.history['loss'], label='Loss')
plt.plot(final_model.history.history['val_loss'], label='val_Loss')
plt.legend()
plt.grid()
plt.title('Loss evolution')

plt.subplot(2, 2, 2)
plt.plot(final_model.history.history['accuracy'], label='accuracy')
plt.plot(final_model.history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.grid()
plt.title('Accuracy evolution')
# Out:
# Text(0.5, 1.0, 'Accuracy evolution')

# %%
model.save('Resnet101.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from keras import models
model = models.load_model('Resnet101.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
batch_size = 32
#!pip install tqdm
import tqdm
validation_generator.reset()
X_test, y_test = next(validation_generator)
for i in tqdm.tqdm(range(int(validation_generator.n/batch_size)-200)): 
  img, label = next(validation_generator)
  X_test = np.append(X_test, img, axis=0 )
  y_test = np.append(y_test, label, axis=0)
print(X_test.shape, y_test.shape)
# Out:
# 100%|██████████| 61/61 [00:43<00:00,  1.40it/s]
# (1984, 227, 227, 3) (1984, 3)

# %%
#predicted_classes = model.predict_classes(X_test)

y_predict=final_model.predict(X_test) 
predicted_classes=np.argmax(y_predict,axis=1)
print(predicted_classes)
# Out:
# 62/62 [==============================] - 12s 165ms/step
# [2 2 0 ... 2 1 1]

# %%
y_test = np.argmax(y_test, axis = 1)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predicted_classes)
plt.figure(figsize = (10,10))
sns.heatmap(cm, annot=True, cmap = 'Pastel1', fmt='g')

# %%
cm_df = pd.DataFrame(cm)
cm_df.columns = [ 'Predicted Accessories','Predicted Apparel', 'Predicted Footwear']
cm_final_df = cm_df.rename(index={0: 'Actually Accessories', 1: 'Actually Apparel', 2: 'Actually Footwear'})
cm_final_df
# Out:
#                       Predicted Accessories  Predicted Apparel  \
# Actually Accessories                     34                273
# Actually Apparel                          2                951
# Actually Footwear                         0                  1
#
#                       Predicted Footwear
# Actually Accessories                 230
# Actually Apparel                      42
# Actually Footwear                    451

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

Precision = precision_score(y_test, predicted_classes,average='macro')
Recall = recall_score(y_test, predicted_classes,average='macro')
F1_score = f1_score(y_test, predicted_classes, average='macro')

df_metrix = pd.DataFrame(data = [(Precision, Recall, F1_score)], columns = ['Precision', 'Recall', 'F1_score'])
df_metrix
# Out:
#    Precision    Recall  F1_score
# 0    0.78152  0.672294   0.58103
